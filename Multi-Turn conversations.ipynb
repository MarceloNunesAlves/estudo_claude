# %%
from dotenv import load_dotenv
load_dotenv(override=True)

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)
answer
# Out:
# Message(id='msg_011CdvzC7o7LtprZzr2ZYY7r', container=None, content=[ThinkingBlock(signature='...', thinking='', type='thinking'), TextBlock(citations=None, text='Quantum computing is a form of computation that harnesses quantum mechanical phenomena — such as superposition, interference, and entanglement — to process information in ways that can solve certain problems more efficiently than classical computers.', type='text')], model='claude-opus-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=18, output_tokens=103, output_tokens_details=OutputTokensDetails(thinking_tokens=32), server_tool_use=None, service_tier='standard'))

# %%
answer = answer.content[1].text

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)
messages
# Out:
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computing is a form of computation that harnesses quantum mechanical phenomena — such as superposition, interference, and entanglement — to process information in ways that can solve certain problems more efficiently than classical computers.'}]

# %%
# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)
final_answer
# Out:
# Message(id='msg_011CdvzDtYSGytD8NZjnRjq1', container=None, content=[ThinkingBlock(signature='...', thinking='', type='thinking'), TextBlock(citations=None, text="Rather than storing information as bits that are strictly 0 or 1, quantum computers use qubits, which can hold a combination of both states at once, allowing a single machine to explore many computational paths simultaneously before interference concentrates the probability on the correct answer.\n\nIf you meant an alternative one-sentence definition instead of a follow-on sentence, just say the word and I'll rephrase.", type='text')], model='claude-opus-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=97, output_tokens=273, output_tokens_details=OutputTokensDetails(thinking_tokens=148), server_tool_use=None, service_tier='standard'))

# %%
final_answer.content[1].text
# Out:
# "Rather than storing information as bits that are strictly 0 or 1, quantum computers use qubits, which can hold a combination of both states at once, allowing a single machine to explore many computational paths simultaneously before interference concentrates the probability on the correct answer.\n\nIf you meant an alternative one-sentence definition instead of a follow-on sentence, just say the word and I'll rephrase."
